# %%
import spacy
# can be used for any languages 
# for only english : python -m spacy download en_core_web_sm is imported 
from spacy import displacy
# visualisation tool / lib

# %%
#read the file
med = "train.dat"
medplus= open(med,"r") 
text = medplus.read()
print(type(text))
# Out:
# <class 'str'>

# %%
#loading the english lang
nlp = spacy.load("en_core_web_sm")

# %%
nlptxt = nlp(text[0:5000]) 
# load 5000 words

# %%
#Segmentatioon of sentences 
#senseg = nlptxt.sents

# %%
#print the text 
#for sent in senseg:
    #print(sent.text_with_ws) # here text doesnot refer to the variable used at the start

# %%
senlist = list()
sent = nlptxt.sents
for lines in sent:
    senlist.append(lines.text)

# %%
print(senlist[0:10])
# Out:
# ['4\tCatheterization laboratory events and hospital outcome with direct angioplasty for acute myocardial infarction To assess the safety of direct infarct angioplasty without antecedent thrombolytic therapy, catheterization laboratory and hospital events were assessed in consecutively treated patients with infarctions involving the left anterior descending (n = 100 patients), right (n = 100), and circumflex (n = 50) coronary arteries.', 'The groups of patients were similar for age (left anterior descending coronary artery, 59 years; right coronary artery, 58 years; circumflex coronary artery, 62 years), patients with multivessel disease (left anterior descending coronary artery, 55%; right coronary artery, 55%; circumflex coronary artery, 64%), and patients with initial grade 0/1 antegrade flow (left anterior descending coronary artery, 79%; right coronary artery, 84%; circumflex coronary artery, 90%).', 'Cardiogenic shock was present in eight patients with infarction of the left ant
# ...

# %%
tokens = list()
for lines in nlptxt:
   tokens.append(lines.text)

# %%
print(tokens[0:6])
# Out:
# ['4', '\t', 'Catheterization', 'laboratory', 'events', 'and']

# %%
#lemmatization
lemmatizer = nlp.get_pipe("lemmatizer")

# %%
lemma_words = [lines.lemma_ for lines in nlptxt]

# %%
postags = list()
for words in nlptxt:
    postags.append([words.pos_, words.tag_, words.is_stop])

# %%
print(lemma_words)
# Out:
# ['4', '\t', 'Catheterization', 'laboratory', 'event', 'and', 'hospital', 'outcome', 'with', 'direct', 'angioplasty', 'for', 'acute', 'myocardial', 'infarction', 'to', 'assess', 'the', 'safety', 'of', 'direct', 'infarct', 'angioplasty', 'without', 'antecedent', 'thrombolytic', 'therapy', ',', 'catheterization', 'laboratory', 'and', 'hospital', 'event', 'be', 'assess', 'in', 'consecutively', 'treat', 'patient', 'with', 'infarction', 'involve', 'the', 'left', 'anterior', 'descending', '(', 'n', '=', '100', 'patient', ')', ',', 'right', '(', 'n', '=', '100', ')', ',', 'and', 'circumflex', '(', 'n', '=', '50', ')', 'coronary', 'artery', '.', 'the', 'group', 'of', 'patient', 'be', 'similar', 'for', 'age', '(', 'leave', 'anterior', 'descend', 'coronary', 'artery', ',', '59', 'year', ';', 'right', 'coronary', 'artery', ',', '58', 'year', ';', 'circumflex', 'coronary', 'artery', ',', '62', 'year', ')', ',', 'patient', 'with', 'multivessel', 'disease', '(', 'leave', 'anterior', 'descend', 'cor
# ...

# %%
print(postags)
# Out:
# [['NUM', 'CD', False], ['SPACE', '_SP', False], ['PROPN', 'NNP', False], ['NOUN', 'NN', False], ['NOUN', 'NNS', False], ['CCONJ', 'CC', True], ['NOUN', 'NN', False], ['NOUN', 'NN', False], ['ADP', 'IN', True], ['ADJ', 'JJ', False], ['NOUN', 'NN', False], ['ADP', 'IN', True], ['ADJ', 'JJ', False], ['ADJ', 'JJ', False], ['NOUN', 'NN', False], ['PART', 'TO', True], ['VERB', 'VB', False], ['DET', 'DT', True], ['NOUN', 'NN', False], ['ADP', 'IN', True], ['ADJ', 'JJ', False], ['NOUN', 'NN', False], ['NOUN', 'NN', False], ['ADP', 'IN', True], ['ADJ', 'JJ', False], ['ADJ', 'JJ', False], ['NOUN', 'NN', False], ['PUNCT', ',', False], ['NOUN', 'NN', False], ['NOUN', 'NN', False], ['CCONJ', 'CC', True], ['NOUN', 'NN', False], ['NOUN', 'NNS', False], ['AUX', 'VBD', True], ['VERB', 'VBN', False], ['ADP', 'IN', True], ['ADV', 'RB', False], ['VERB', 'VBN', False], ['NOUN', 'NNS', False], ['ADP', 'IN', True], ['NOUN', 'NNS', False], ['VERB', 'VBG', False], ['DET', 'DT', True], ['ADJ', 'JJ', False], [
# ...

# %%
entities = list()
for ent in nlptxt.ents:
    entities.append([ent.text, ent.label_])

# %%
print(entities)
# Out:
# [['4', 'CARDINAL'], ['100', 'CARDINAL'], ['100', 'CARDINAL'], ['50', 'CARDINAL'], ['59 years', 'DATE'], ['58 years', 'DATE'], ['62 years', 'DATE'], ['55%', 'PERCENT'], ['55%', 'PERCENT'], ['64%', 'PERCENT'], ['0/1', 'CARDINAL'], ['79%', 'PERCENT'], ['84%', 'PERCENT'], ['90%', 'PERCENT'], ['Cardiogenic', 'NORP'], ['eight', 'CARDINAL'], ['four', 'CARDINAL'], ['four', 'CARDINAL'], ['10', 'CARDINAL'], ['eight', 'CARDINAL'], ['four', 'CARDINAL'], ['16', 'CARDINAL'], ['16', 'CARDINAL'], ['six', 'CARDINAL'], ['234', 'CARDINAL'], ['less than 0.001', 'CARDINAL'], ['5', 'CARDINAL'], ['Renal', 'ORG'], ['Three', 'CARDINAL'], ['An additional 23', 'CARDINAL'], ['the past ten years', 'DATE'], ['Fever', 'GPE'], ['less than half', 'CARDINAL'], ['17', 'CARDINAL'], ['9', 'CARDINAL'], ['Staphylococcus', 'PERSON'], ['8', 'CARDINAL'], ['S.', 'ORG'], ['Reflux', 'PERSON'], ['5', 'CARDINAL'], ['2', 'CARDINAL'], ['10', 'CARDINAL'], ['38%', 'PERCENT'], ['16', 'CARDINAL'], ['62%', 'PERCENT'], ['2', 'CARDINAL'],
# ...

# %%
displacy.serve(nlptxt, style="ent")
# Out:
# c:\Users\Ramya\anaconda3\lib\site-packages\spacy\displacy\__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# ...

# %%
displacy.serve(nlptxt, style="dep")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="91dd5d91693e4b4680326a681c317e67-0" class="displacy" width="128325" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# ...
